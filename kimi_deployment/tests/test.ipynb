# %%
import requests
import numpy as np
import soundfile as sf

# === 1. 加载音频文件，转 float32 PCM ===
wav_path = "/data/kimi_deployment/tests/test_audios/asr_example_cantonese.wav"
audio_data, sample_rate = sf.read(wav_path, dtype="float32")

# 转为二进制流（float32）
pcm_bytes = audio_data.astype(np.float32).tobytes()

# === 2. 构造请求头 + 发送 POST 请求 ===
headers = {
    "name": "self_record27.wav",
    #'language':  'zh',
    'use_custom_language_classifier': 'true'
}

response = requests.post("http://127.0.0.1:8000/transcribe_websocket", headers=headers, data=pcm_bytes)

# === 3. 打印结果 ===
print(response.status_code)
print(response.text)
# Out:
# 200
# {"result":[{"status":0,"text":"我安安陪人supermarket会买野。","language":"Auto detection","prompt":"请转写以下音频","start":0,"end":5.6285625}],"info":null,"status":0}

# %%
import websocket
import json
import soundfile as sf
import numpy as np
import time

# 1. 连接
ws = websocket.create_connection("ws://127.0.0.1:9091")

# 2. 发送初始化参数
options = {
  "uid": "test_user",
  "token": "xxx",
  "name": "test.wav",
  "initial_prompt": "",
  "version": "1.0",
  "model": "faster_whisper",
  "user_id": "abc123",
  "type_name": "developer"
}
ws.send(json.dumps(options))



# 改成 int16 格式 PCM
audio_data, sample_rate = sf.read("/data/kimi_deployment/tests/test_audios/asr_example_cantonese.wav")
pcm_bytes = (audio_data * 32768.0).astype(np.int16).tobytes()
# 4. 发送音频帧
ws.send(pcm_bytes, opcode=websocket.ABNF.OPCODE_BINARY)
 # 模拟实时流式传输，可以根据需要调整


ws.send(b"END_OF_AUDIO")

# 6. 获取返回
while True:
    try:
        msg = ws.recv()
        time.sleep(1)
        print("收到返回：", msg)
    except:
        break

ws.close()
# Out:
# 收到返回： {"uid": "test_user", "message": "SERVER_READY", "code": 0, "status": "SERVER_READY", "backend": "vvVoiceServer"}
# 收到返回： {"uid": "test_user", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": true}
# 收到返回： {"uid": "test_user", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": true}
# 收到返回： {"uid": "test_user", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": true}
# 收到返回： {"uid": "test_user", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": true}
# 收到返回： {"uid": "test_user", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": true}
# 收到返回： {"uid": "test_user", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": true}
# 收到返回： {"uid": "test_user", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": true}
# 收到返回：

# %%
import soundfile as sf
import websocket
import time
import numpy as np

def send_audio_ws(audio_path, ws_url, frame_duration=0.4):
    # 1. 读取音频（float32），并检查采样率
    audio_data, sample_rate = sf.read(audio_path)
    assert sample_rate == 16000, "音频采样率必须为 16kHz"

    # 2. 转换为 int16 PCM 格式
    int16_audio = (audio_data * 32768.0).astype(np.int16)
    pcm_bytes = int16_audio.tobytes()

    # 3. 计算帧大小（按时间分帧，如每 0.5 秒）
    frame_size = int(sample_rate * frame_duration)  # 0.5秒 * 16000 = 8000 samples
    num_frames = len(int16_audio) // frame_size

    # 4. 连接 WebSocket
    ws = websocket.create_connection(ws_url)

    # 5. 发送初始化配置（你实际项目可能需要先发 JSON 配置）
    config = {
        "uid": "user001",
        "model": "small.en",
        "task": "transcribe",
        "token": "mock_token_123",
        "version": "v1",
        "use_vad": True,
        "name": "demo.wav"
    }
    ws.send(json.dumps(config))

    time.sleep(0.1)  # 等待服务端准备好

    # 6. 分帧发送 PCM 数据
    for i in range(num_frames + 1):
        start = i * frame_size
        end = start + frame_size
        frame = int16_audio[start:end]
        if len(frame) == 0:
            continue
        ws.send(frame.tobytes(), opcode=websocket.ABNF.OPCODE_BINARY)
        time.sleep(frame_duration)  # 可调：模拟实时发送

    

    # 7. 通知服务端音频结束
    ws.send(b"END_OF_AUDIO")

    # 8. 等待识别结果
    while True:
        try:
            result = ws.recv()
            print("[结果] ", result)
            if '"is_end": true' in result:
                print("✅ 服务端识别结束")
                break
        except Exception as e:
            print(f"[错误] {e}")
            break

    ws.close()

# %%
send_audio_ws(
    "/data/kimi_deployment/tests/test_audios/asr_example_cantonese.wav",
    "ws://localhost:9091"
)
# Out:
# [结果]  {"uid": "user001", "message": "SERVER_READY", "code": 0, "status": "SERVER_READY", "backend": "vvVoiceServer"}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "0.800", "text": "\u6211\u60f3\u8981\u4e70samsung\u7684\u88e4\u5b50\u3002"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "1.200", "text": "\u6211\u4eec"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "1.200", "text": "\u6211\u4eec"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "1.200", "text": "\u6211\u4eec"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "1.600", "text": "\u7f57\u6069\u6069"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "1.600", "text": "\u7f57\u6069\u6069"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "2.000", "text": "\u9f99\u5b89\u5b89\u53ef\u4ee5\u3002"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "2.000", "text": "\u9f99\u5b89\u5b89\u53ef\u4ee5\u3002"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "2.400", "text": "\u8ba9\u5b89\u5b89\u966a\u4f60superman."}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "2.800", "text": "\u6c38\u5b89\u5b89\u914d\u996esupermarket."}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "3.200", "text": "\u6211\u5b89\u5b89\u6392\u4e00supermarket\u4f1a\u5417\uff1f"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "3.600", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u53bb\u4e70\u91ce\u3002"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "4.400", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u53bb\u4e70\u91ce\u3002"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "4.800", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u53bb\u4e70\u91ce\u3002"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.200", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u53bb\u4e70\u91ce\u3002"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": false}
# [结果]  {"uid": "user001", "code": 0, "status": "RESULT", "segments": [{"start": "0.000", "end": "5.629", "text": "\u6211\u5b89\u5b89\u966a\u4ebasupermarket\u4f1a\u4e70\u91ce\u3002"}], "is_end": true}
# ✅ 服务端识别结束

# %%
import json
import time
import random
import threading
import numpy as np
import soundfile as sf
import websocket

WS_URL = "ws://127.0.0.1:9091"

# ========= 可调参数 =========
FRAME_MS = 40            # 每帧 40ms（常见 20~50ms）
JITTER_MS = 10           # 发送抖动 ±10ms
INSERT_SILENCE_MS = 600  # 段与段之间插入静音的时长（毫秒）
REALTIME = True          # True = 按时延真实发送；False = 不等待（更快）
LANGUAGE = "zh"          # 或 "en" 等；不需要可设为 None
INITIAL_PROMPT = "请转写以下音频"  # 不需要可设为空字符串
UID = "user_multi_001"

# 多段音频（顺序播放）
SEGMENTS = [
    "/path/to/seg1.wav",
    "/path/to/seg2.wav",
    "/path/to/seg3.wav",
]

def _resample_linear(x, src_sr, dst_sr):
    if src_sr == dst_sr:
        return x
    n = int(round(len(x) * dst_sr / src_sr))
    return np.interp(np.linspace(0, len(x), n, endpoint=False), np.arange(len(x)), x).astype(np.float32)

def _load_pcm16(path, target_sr=16000, mono=True):
    audio, sr = sf.read(path, always_2d=False)
    if audio.ndim == 2 and mono:
        audio = audio.mean(axis=1)
    audio = _resample_linear(audio.astype(np.float32), sr, target_sr)
    # 归一 & 转 PCM16
    pcm16 = (np.clip(audio, -1.0, 1.0) * 32767.0).astype(np.int16)
    return pcm16, target_sr

def _send_stream(ws, pcm16, sr, frame_ms=FRAME_MS, jitter_ms=JITTER_MS, realtime=REALTIME):
    bytes_per_sample = 2
    samples_per_ms = sr // 1000
    frame_n = frame_ms * samples_per_ms

    idx = 0
    while idx < len(pcm16):
        end = min(len(pcm16), idx + frame_n)
        frame = pcm16[idx:end]
        if len(frame) == 0:
            break
        ws.send(frame.tobytes(), opcode=websocket.ABNF.OPCODE_BINARY)
        idx = end

        if realtime:
            # 模拟抖动
            sleep_ms = frame_ms + random.randint(-jitter_ms, jitter_ms)
            time.sleep(max(0.0, sleep_ms / 1000.0))

def _send_silence(ws, ms, sr=16000, frame_ms=FRAME_MS, jitter_ms=JITTER_MS, realtime=REALTIME):
    samples = (sr * ms) // 1000
    if samples <= 0:
        return
    silence = np.zeros(samples, dtype=np.int16)
    _send_stream(ws, silence, sr, frame_ms, jitter_ms, realtime)

def _recv_loop(ws, stop_event):
    ws.settimeout(30)
    last = None
    while not stop_event.is_set():
        try:
            msg = ws.recv()
            if not msg:
                break
            # 去重打印
            if msg != last:
                print("← [RECV]", msg)
                last = msg
            # 简单结束检测
            if '"status":"RESULT"' in msg and '"is_end": true' in msg:
                # 等服务端清尾
                time.sleep(0.1)
                stop_event.set()
                break
        except Exception as e:
            # 正常超时/断开都到这里
            break

# %%
import websocket
import sounddevice as sd
import numpy as np
import threading
import json
import time

# 音频参数
SAMPLE_RATE = 16000
FRAME_DURATION = 0.5  # 每帧0.5秒
FRAME_SIZE = int(SAMPLE_RATE * FRAME_DURATION)

# WebSocket 地址（可用 SSH 隧道或公网IP）
WS_URL = "ws://localhost:9090"  # 或 "ws://your_ip:9090"

# 初始化连接并发送配置信息
def init_ws():
    ws = websocket.create_connection(WS_URL)
    config = {
        "uid": "user001",
        "model": "small.en",
        "task": "transcribe",
        "token": "mock_token_123",
        "version": "v1",
        "use_vad": True,
        "name": "mic_test.wav"
    }
    ws.send(json.dumps(config))
    return ws

# 音频采集线程
def record_and_send(ws):
    def callback(indata, frames, time_info, status):
        # 转 float32 → int16 PCM → bytes
        pcm_bytes = (indata[:, 0] * 32768).astype(np.int16).tobytes()
        ws.send(pcm_bytes, opcode=websocket.ABNF.OPCODE_BINARY)

    with sd.InputStream(samplerate=SAMPLE_RATE, channels=1, dtype='float32',
                        blocksize=FRAME_SIZE, callback=callback):
        print("🎙️ 开始说话，按 Ctrl+C 停止...")
        try:
            while True:
                time.sleep(0.1)
        except KeyboardInterrupt:
            print("⏹️ 停止录音")
            ws.send(b"END_OF_AUDIO")

# 接收转写结果
def receive(ws):
    while True:
        try:
            msg = ws.recv()
            print("📜 识别结果：", msg)
            if '"is_end": true' in msg:
                break
        except Exception as e:
            print("[错误]", e)
            break

# 主函数
if __name__ == "__main__":
    ws = init_ws()

    # 启动接收线程
    recv_thread = threading.Thread(target=receive, args=(ws,))
    recv_thread.start()

    # 开始录音并发送
    record_and_send(ws)

    ws.close()
# Out:
# 📜 识别结果： {"uid": "user001", "message": "SERVER_READY", "code": 0, "status": "SERVER_READY", "backend": "vvVoiceServer"}
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[78], line 69
#      66 recv_thread.start()
#      68 # 开始录音并发送
# ---> 69 record_and_send(ws)
#      71 ws.close()
#
# Cell In[78], line 38, in record_and_send(ws)
#      35     pcm_bytes = (indata[:, 0] * 32768).astype(np.int16).tobytes()
#      36     ws.send(pcm_bytes, opcode=websocket.ABNF.OPCODE_BINARY)
# ---> 38 with sd.InputStream(samplerate=SAMPLE_RATE, channels=1, dtype='float32',
#      39                     blocksize=FRAME_SIZE, callback=callback):
#      40     print("🎙️ 开始说话，按 Ctrl+C 停止...")
#      41     try:
#
# File ~/miniconda3/envs/whisperlive/lib/python3.8/site-packages/sounddevice.py:1429, in InputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1399 def __init__(self, samplerate=None, blocksize=None,
#    1400              device=None, channels=None, dtype=None, latency=None,
#    1401              extra_settings=None, callback=None, finished_callback=None,
#    1402              clip_off=None, dither_off=None, never_drop_input=None,
#    1403              prime_output_buffers_using_stream_callback=None):
#    1404     """PortAudio input stream (using NumPy).
#    1405
#    1406     This has the same methods and attributes as `Stream`, except
#    (...)
#    1427
#    1428     """
# -> 1429     _StreamBase.__init__(self, kind='input', wrap_callback='array',
#    1430                          **_remove_self(locals()))
#
# File ~/miniconda3/envs/whisperlive/lib/python3.8/site-packages/sounddevice.py:825, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     822         samplerate = isamplerate
#     823 else:
#     824     parameters, self._dtype, self._samplesize, samplerate = \
# --> 825         _get_stream_parameters(kind, device, channels, dtype, latency,
#     826                                extra_settings, samplerate)
#     827     self._device = parameters.device
#     828     self._channels = parameters.channelCount
#
# File ~/miniconda3/envs/whisperlive/lib/python3.8/site-packages/sounddevice.py:2683, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2680     samplerate = default.samplerate
#    2682 device = _get_device_id(device, kind, raise_on_error=True)
# -> 2683 info = query_devices(device)
#    2684 if channels is None:
#    2685     channels = info['max_' + kind + '_channels']
#
# File ~/miniconda3/envs/whisperlive/lib/python3.8/site-packages/sounddevice.py:569, in query_devices(device, kind)
#     567 info = _lib.Pa_GetDeviceInfo(device)
#     568 if not info:
# --> 569     raise PortAudioError(f'Error querying device {device}')
#     570 assert info.structVersion == 2
#     571 name_bytes = _ffi.string(info.name)
#
# PortAudioError: Error querying device -1
# 📜 识别结果： {"uid": "user001", "code": 1002, "status": "TIMEOUT", "message": "Recv Time out!"}
# 📜 识别结果：
# [错误] Connection to remote host was lost.

# %%
import sounddevice as sd
print(sd.query_devices())

# %%
import whisper_live.transcriber
import inspect

print(inspect.getfile(whisper_live.transcriber))
# Out:
# /root/miniconda3/envs/whisperlive/lib/python3.8/site-packages/whisper_live/transcriber.py

# %%
import sys
sys.path.insert(0, "/data/WhisperLive/whisper_live")

from transcriber import WhisperModel  # 现在就是本地的了
model1 = WhisperModel("/root/ASR_TTS_improvement/models/ct2-whisper-lora",
                      device="cuda", compute_type="float16",with_language_classifier = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 sys.path.insert(0, "/data/WhisperLive/whisper_live")
#       4 from transcriber import WhisperModel  # 现在就是本地的了
# ----> 5 model1 = WhisperModel("/root/ASR_TTS_improvement/models/ct2-whisper-lora",
#       6                       device="cuda", compute_type="float16",with_language_classifier = True)
#
# TypeError: __init__() got an unexpected keyword argument 'with_language_classifier'

# %%
import os
import subprocess

pid = os.getpid()
result = subprocess.run(["lsof", "-p", str(pid)], stdout=subprocess.PIPE, text=True)
for line in result.stdout.splitlines():
    if ".so" in line:
        print(line)
# Out:
# pt_main_t 320204 root  mem       REG              0,199 563259240  14026813 /usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6
# pt_main_t 320204 root  mem       REG              0,199  90853824  14026823 /usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6
# pt_main_t 320204 root  mem       REG                8,2   1942744 113515753 /usr/lib/x86_64-linux-gnu/libnvidia-ml.so.535.183.01
# pt_main_t 320204 root  mem       REG               8,33     21481  26747989 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libuuid-f64cda11.so.1.3.0
# pt_main_t 320204 root  mem       REG               8,33    498873  26678390 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/audio/codeccontext.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    268752  26676864 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/charset_normalizer/md__mypyc.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    416937  26678304 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/filter/pad.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    400465  26678302 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/filter/link.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    913041  26678314 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/filter/graph.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     17049  26748001 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libXau-00ec42fe.so.6.0.0
# pt_main_t 320204 root  mem       REG               8,33    679417  26678311 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/filter/context.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    847449  26678309 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/filter/filter.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    621833  26678398 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/audio/resampler.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    601393  26678405 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/audio/fifo.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    371665  26678404 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/audio/stream.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    379945  26678395 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/audio/plane.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    737057  26678396 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/audio/layout.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    437369  26678346 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/video/plane.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    396353  26678331 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/plane.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    630113  26678354 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/video/reformatter.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    753273  26678349 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/video/format.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    831273  26678287 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/container/output.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    835385  26678286 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/container/input.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    654873  26678377 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/sidedata/motionvectors.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     45361  26748003 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libxcb-xfixes-9be3ba6f.so.0.0.0
# pt_main_t 320204 root  mem       REG               8,33    367569  26678352 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/video/stream.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    638345  26678408 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/stream.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    585033  26678371 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/format.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    699881  26678283 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/container/streams.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    757417  26678375 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/sidedata/sidedata.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    564841  26678337 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/dictionary.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    531761  26678359 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/packet.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1167273  26678289 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/container/core.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1273585  26678322 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/codec/context.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   2769233  26678339 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/video/frame.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1220105  26678334 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/error.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     21801  26747974 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libxcb-shape-25c2b258.so.0.0.0
# pt_main_t 320204 root  mem       REG               8,33    621937  26678282 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/container/pyio.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1523569  26678372 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/enum.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1126273  26747968 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libharfbuzz-d40f381a.so.0.40100.0
# pt_main_t 320204 root  mem       REG               8,33  19369233  26747973 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libx265-d8690e8d.so.199
# pt_main_t 320204 root  mem       REG               8,33    347121  26678292 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/utils.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    543801  26678276 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/option.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    371961  26678400 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/audio/format.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    855825  26678323 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/codec/codec.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1597097  26747990 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libunistring-aeeab030.so.2.1.0
# pt_main_t 320204 root  mem       REG               8,33     21401  26747991 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libxcb-shm-7a199f70.so.0.0.0
# pt_main_t 320204 root  mem       REG               8,33    478433  26678327 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/buffer.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    457985  26678273 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/frame.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    798289  26678388 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/audio/frame.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    949857  26678299 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/logging.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    195889  26747983 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libpng16-1f529098.so.16.37.0
# pt_main_t 320204 root  mem       REG               8,33    312385  26747961 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libhogweed-5d799758.so.6.4
# pt_main_t 320204 root  mem       REG               8,33    302641  26747998 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libnettle-cb75a9d6.so.8.4
# pt_main_t 320204 root  mem       REG               8,33    717657  26747976 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libfreetype-19bd6cfb.so.6.17.1
# pt_main_t 320204 root  mem       REG               8,33    210465  26747988 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libxcb-65da195c.so.1.1.0
# pt_main_t 320204 root  mem       REG               8,33    334865  26678356 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/descriptor.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    304809  26747996 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libfontconfig-99ba2620.so.1.12.0
# pt_main_t 320204 root  mem       REG               8,33    229129  26747970 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libass-8499ab98.so.9.1.3
# pt_main_t 320204 root  mem       REG               8,33    668433  26747979 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libxvidcore-d29bca61.so.4.3
# pt_main_t 320204 root  mem       REG               8,33   2267921  26747975 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libx264-6c449319.so.164
# pt_main_t 320204 root  mem       REG               8,33    713145  26747977 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libvorbisenc-0d9d5bdf.so.2.0.12
# pt_main_t 320204 root  mem       REG               8,33    244425  26747993 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libvorbis-f4a9a6fd.so.0.4.9
# pt_main_t 320204 root  mem       REG               8,33    371425  26747994 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libopus-70bda348.so.0.8.0
# pt_main_t 320204 root  mem       REG               8,33    532569  26747967 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libopenjp2-0d101c52.so.2.4.0
# pt_main_t 320204 root  mem       REG               8,33    417001  26747978 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libmp3lame-3ecc6556.so.0.0.0
# pt_main_t 320204 root  mem       REG               8,33   7285769  26747982 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libaom-e9efed4a.so.3.2.0
# pt_main_t 320204 root  mem       REG               8,33   1578105  26747963 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libdav1d-dd448d93.so.5.1.1
# pt_main_t 320204 root  mem       REG               8,33   2127801  26747992 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libvpx-014cc4e0.so.8.0.1
# pt_main_t 320204 root  mem       REG               8,33   2176425  26747964 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libgnutls-58994bd7.so.30.31.0
# pt_main_t 320204 root  mem       REG               8,33    495241  26747969 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libgmp-dbb9f291.so.10.4.1
# pt_main_t 320204 root  mem       REG               8,33    326105  26747995 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libbluray-69850b93.so.2.1.2
# pt_main_t 320204 root  mem       REG               8,33   1609769  26747997 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libxml2-cb941fce.so.2.9.13
# pt_main_t 320204 root  mem       REG               8,33    574889  26747972 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libswscale-6bb613b9.so.7.1.100
# pt_main_t 320204 root  mem       REG               8,33   4486481  26747965 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libavfilter-660a92e7.so.9.3.100
# pt_main_t 320204 root  mem       REG               8,33    926713  26747971 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libavutil-74a65dc0.so.58.2.100
# pt_main_t 320204 root  mem       REG               8,33  13613193  26747980 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libavcodec-2cdd7da0.so.60.3.100
# pt_main_t 320204 root  mem       REG               8,33   2638001  26748000 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libavformat-971e3cea.so.60.3.100
# pt_main_t 320204 root  mem       REG               8,33  11728344  26742903 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/tokenizers/tokenizers.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   2397464  26676157 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/yaml/_yaml.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG              0,199  54409816  13769564 /usr/local/cuda-11.8/targets/x86_64-linux/lib/libnvrtc.so.11.8.89
# pt_main_t 320204 root  mem       REG               8,33    143513  26747987 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libtwolame-72d74ef7.so.0.0.0
# pt_main_t 320204 root  mem       REG                8,2  29380816 113515751 /usr/lib/x86_64-linux-gnu/libcuda.so.535.183.01
# pt_main_t 320204 root  mem       REG               8,33 186070240  26675876 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/nccl/lib/libnccl.so.2
# pt_main_t 320204 root  mem       REG               8,33    314377  26678328 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/bytesource.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    172889  26747984 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libopencore-amrnb-393dbae2.so.0.0.3
# pt_main_t 320204 root  mem       REG               8,33 574565016  26675810 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/cublas/lib/libcublasLt.so.11
# pt_main_t 320204 root  mem       REG               8,33    196537  26748002 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/liblzma-af70179d.so.5.4.4
# pt_main_t 320204 root  mem       REG               8,33  94729912  26675808 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/cublas/lib/libcublas.so.11
# pt_main_t 320204 root  mem       REG               8,33    128873  26747960 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libfribidi-baef595b.so.0.4.0
# pt_main_t 320204 root  mem       REG               8,33 101334448  26675945 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/curand/lib/libcurand.so.10
# pt_main_t 320204 root  mem       REG               8,33    189864  26675715 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_multibytecodec.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     75001  26747981 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libpostproc-57315235.so.57.1.100
# pt_main_t 320204 root  mem       REG               8,33  34574129  26741728 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libcusparseLt-f8b4a9fb.so.0
# pt_main_t 320204 root  mem       REG               8,33 279161544  26675788 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/cufft/lib/libcufft.so.10
# pt_main_t 320204 root  mem       REG               8,33    108521  26747986 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libspeex-b6a53f7a.so.1.5.1
# pt_main_t 320204 root  mem       REG               8,33 279899536  26676142 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/cusparse/lib/libcusparse.so.11
# pt_main_t 320204 root  mem       REG               8,33   7199856  26675990 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/cuda_cupti/lib/libcupti.so.11.8
# pt_main_t 320204 root  mem       REG               8,33    132417  26747985 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libswresample-b9c8e93a.so.4.10.100
# pt_main_t 320204 root  mem       REG               8,33    150200  26675913 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/cudnn/lib/libcudnn.so.8
# pt_main_t 320204 root  mem       REG               8,33     43049  26747999 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libogg-bbd52b06.so.0.8.5
# pt_main_t 320204 root  mem       REG               8,33     90217  26747966 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libavdevice-576e8d1a.so.60.1.100
# pt_main_t 320204 root  mem       REG               8,33 946503433  26741730 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libtorch_cuda.so
# pt_main_t 320204 root  mem       REG               8,33 482044169  26741729 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so
# pt_main_t 320204 root  mem       REG               8,33  26003073  26741732 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libtorch_python.so
# pt_main_t 320204 root  mem       REG               8,33    169089  26741734 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libgomp-a34b3233.so.1
# pt_main_t 320204 root  mem       REG               8,33     82609  26747962 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av.libs/libopencore-amrwb-9db94aa9.so.0.0.3
# pt_main_t 320204 root  mem       REG               8,33     40136  26675846 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/nvtx/lib/libnvToolsExt.so.1
# pt_main_t 320204 root  mem       REG               8,33   1327001  26741733 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libc10.so
# pt_main_t 320204 root  mem       REG               8,33    652121  26741735 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libc10_cuda.so
# pt_main_t 320204 root  mem       REG               8,33    679264  26676108 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/nvidia/cuda_runtime/lib/libcudart.so.11.0
# pt_main_t 320204 root  mem       REG               8,33    185632  26675747 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/cmath.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    255873  26741725 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libtorch.so
# pt_main_t 320204 root  mem       REG               8,33    247608  26679983 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy.libs/libquadmath-96973f99.so.0.0.0
# pt_main_t 320204 root  mem       REG               8,33    175145  26678335 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/av/_core.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    997104  26746557 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/_generator.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    126880  26746513 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/_pcg64.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    106008  26746561 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/_philox.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    407416  26746560 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/_bounded_integers.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    320088  26746512 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/_common.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   2686064  26679981 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy.libs/libgfortran-040039e1.so.5.0.0
# pt_main_t 320204 root  mem       REG               8,33     52745  26741727 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libshm.so
# pt_main_t 320204 root  mem       REG               8,33    227160  26746566 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/bit_generator.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    810416  26746563 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/mtrand.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33  32955056  26679982 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy.libs/libopenblas64_p-r0-15028c96.3.21.so
# pt_main_t 320204 root  mem       REG               8,33   6311424  26747183 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/core/_multiarray_umath.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    165393  36503602 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/ctranslate2.libs/libcudnn-463fd6d5.so.8.9.7
# pt_main_t 320204 root  mem       REG               8,33     16064  26676857 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/charset_normalizer/md.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    124472  26746479 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/_mt19937.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    230272  26747595 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/linalg/_umath_linalg.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    168193  36503600 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/ctranslate2.libs/libgomp-a34b3233.so.1.0.0
# pt_main_t 320204 root  mem       REG               8,33     55920  26675742 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_multiprocessing.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     37857  26681270 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/_C.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     21185  26741724 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/torch/lib/libtorch_global_deps.so
# pt_main_t 320204 root  mem       REG               8,33     97032  26747234 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/fft/_pocketfft_internal.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33  71690457  36503601 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/ctranslate2.libs/libctranslate2-d3638643.so.4.4.0
# pt_main_t 320204 root  mem       REG               8,33     76128  26746492 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/random/_sfc64.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    174880  26746959 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/numpy/core/_multiarray_tests.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33  58941585  36503567 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/ctranslate2/_ext.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     36064  26622750 /root/miniconda3/envs/whisper/lib/libuuid.so.1
# pt_main_t 320204 root  mem       REG               8,33     27744  26675739 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_uuid.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1387984  26675766 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_decimal.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    297176  26622731 /root/miniconda3/envs/whisper/lib/libtinfow.so.6
# pt_main_t 320204 root  mem       REG               8,33    273760  26624532 /root/miniconda3/envs/whisper/lib/libncursesw.so.6
# pt_main_t 320204 root  mem       REG               8,33    464120  26675720 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_curses.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     15864  27396272 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/tornado/speedups.abi3.so
# pt_main_t 320204 root  mem       REG               8,33    211720  26675718 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/array.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     57520  27398436 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/_proxy_steerable.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     62720  27398444 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/_device.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     41240  27398429 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/_version.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     92032  27398670 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/_poll.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     59032  27398440 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/utils.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    185736  27398702 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/socket.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     90808  27398659 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/context.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    130608  27398690 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/message.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    649032  26624509 /root/miniconda3/envs/whisper/lib/libgcc_s.so.1
# pt_main_t 320204 root  mem       REG               8,33  17981480  27399211 /root/miniconda3/envs/whisper/lib/libstdc++.so.6.0.29
# pt_main_t 320204 root  mem       REG               8,33    423072  27395580 /root/miniconda3/envs/whisper/lib/libsodium.so.23.3.0
# pt_main_t 320204 root  mem       REG               8,33    852032  27395880 /root/miniconda3/envs/whisper/lib/libzmq.so.5.2.5
# pt_main_t 320204 root  mem       REG               8,33     99016  27398682 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/constants.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     50480  26622796 /root/miniconda3/envs/whisper/lib/libffi.so.8
# pt_main_t 320204 root  mem       REG               8,33    503040  26675758 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_ctypes.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1169040  26675702 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/unicodedata.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    221872  26675760 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_asyncio.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     29400  26675744 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_contextvars.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1143576  26624517 /root/miniconda3/envs/whisper/lib/libssl.so.3
# pt_main_t 320204 root  mem       REG               8,33    462688  26675708 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_ssl.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   1566672  26624523 /root/miniconda3/envs/whisper/lib/libsqlite3.so.0
# pt_main_t 320204 root  mem       REG               8,33    372464  26675738 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_sqlite3.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    121112  26675712 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_csv.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    544920  26675722 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_datetime.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    112872  26675711 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/binascii.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    431240  26675762 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_sha3.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    222240  26675701 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_blake2.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33   6206616  26622730 /root/miniconda3/envs/whisper/lib/libcrypto.so.3
# pt_main_t 320204 root  mem       REG               8,33    138384  26675730 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_hashlib.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     44584  26675721 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/resource.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     59256  26675748 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/fcntl.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     55688  26675705 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/termios.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     52208  26675754 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_random.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     83504  26675740 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_sha512.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     46152  27398433 /root/miniconda3/envs/whisper/lib/python3.8/site-packages/zmq/backend/cython/error.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     79688  26675717 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_lsprof.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     50016  26675726 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_queue.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    528968  26675716 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_pickle.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    179248  26675696 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_struct.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    270712  26675706 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_socket.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     31008  26675723 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_opcode.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     52808  26675704 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/grp.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    180952  26622785 /root/miniconda3/envs/whisper/lib/liblzma.so.5
# pt_main_t 320204 root  mem       REG               8,33    126504  26675757 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_lzma.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    230480  26622713 /root/miniconda3/envs/whisper/lib/libbz2.so.1.0
# pt_main_t 320204 root  mem       REG               8,33     75048  26675714 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_bz2.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33     37296  26675761 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_bisect.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    248648  26675700 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    101032  26675697 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/select.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    166552  26675725 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_json.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    102712  26675756 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_heapq.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG               8,33    112800  26624528 /root/miniconda3/envs/whisper/lib/libz.so.1
# pt_main_t 320204 root  mem       REG               8,33    110136  26675699 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/zlib.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG              0,199     14664   8941536 /usr/lib/x86_64-linux-gnu/librt.so.1
# pt_main_t 320204 root  mem       REG              0,199   2216304   8941439 /usr/lib/x86_64-linux-gnu/libc.so.6
# pt_main_t 320204 root  mem       REG              0,199    940560   8941491 /usr/lib/x86_64-linux-gnu/libm.so.6
# pt_main_t 320204 root  mem       REG              0,199     14432   8941564 /usr/lib/x86_64-linux-gnu/libutil.so.1
# pt_main_t 320204 root  mem       REG              0,199     14432   8941453 /usr/lib/x86_64-linux-gnu/libdl.so.2
# pt_main_t 320204 root  mem       REG              0,199     21448   8941534 /usr/lib/x86_64-linux-gnu/libpthread.so.0
# pt_main_t 320204 root  mem       REG               8,33     65008  26675703 /root/miniconda3/envs/whisper/lib/python3.8/lib-dynload/_posixsubprocess.cpython-38-x86_64-linux-gnu.so
# pt_main_t 320204 root  mem       REG              0,199    240936   8941421 /usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2

# %%
import ctranslate2

print("CTranslate2 version:", ctranslate2.__version__)
print("CTranslate2 available devices:", ctranslate2.get_supported_compute_types("cuda"))
# Out:
# CTranslate2 version: 4.4.0
# CTranslate2 available devices: {'int8_bfloat16', 'bfloat16', 'int8_float16', 'float32', 'float16', 'int8_float32', 'int8'}

# %%
import os
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

# 当前 CUDA 版本（PyTorch 编译时所用）
print("Compiled CUDA version:", torch.version.cuda)

# 当前运行时实际加载的 CUDA 库
torch.cuda.init()
print("Loaded CUDA version:", torch._C._cuda_getCompiledVersion())
print("CUDA device name:", torch.cuda.get_device_name(0))
print("LD_LIBRARY_PATH:", os.environ.get("LD_LIBRARY_PATH"))
print("PATH:", os.environ.get("PATH"))
print("PYTHONPATH:", os.environ.get("PYTHONPATH"))

import ctypes.util

print("libcublas path:", ctypes.util.find_library("cublas"))
print("libcudnn path:", ctypes.util.find_library("cudnn"))

import os
import subprocess

pid = os.getpid()
print(f"Python PID: {pid}")

# 显示所有当前 Python 进程加载的共享库
print("\nLoaded shared libraries (filtered by cublas):")
subprocess.run(f"lsof -p {pid} | grep cublas", shell=True)
# Out:
# Torch version: 2.3.1+cu118
# CUDA available: True
# Compiled CUDA version: 11.8
# Loaded CUDA version: 11080
# CUDA device name: NVIDIA A40
# LD_LIBRARY_PATH: /root/miniconda3/envs/whisper/lib:/usr/local/cuda-11.8/lib64
# PATH: /root/miniconda3/envs/whisper/bin:/root/.vscode-server/bin/848b80aeb52026648a8ff9f7c45a9b0a80641e2e/bin/remote-cli:/usr/local/cuda-11.8/bin:/root/miniconda3/envs/whisper/bin:/root/miniconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin
# PYTHONPATH: third_party/Matcha-TTS
# libcublas path: libcublas.so.11
# libcudnn path: libcudnn.so.8
# Python PID: 320204
#
# Loaded shared libraries (filtered by cublas):
# CompletedProcess(args='lsof -p 320204 | grep cublas', returncode=0)
